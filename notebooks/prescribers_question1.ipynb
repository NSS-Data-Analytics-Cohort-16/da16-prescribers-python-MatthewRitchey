# %%
import pandas as pd
from sqlalchemy import create_engine, text

# create engine for this notebook
engine = create_engine("postgresql://postgres:postgres@localhost:5432/Prescribers")

# %% [markdown]
# # ⦁	Which Tennessee counties had a disproportionately high number of opioid prescriptions?

# %% [markdown]
# tables needed for this project:  prescription - prescriber - drug - zip_fips - fips_county.

# %%
# prescription table
query = "SELECT * FROM prescription"
with engine.connect() as connection:
    rx = pd.read_sql(text(query), con=connection)

rx.head()
# Out:
#             npi       drug_name  bene_count  total_claim_count  \
# 0  1.427076e+09  RALOXIFENE HCL         NaN               18.0
# 1  1.003858e+09     GLIMEPIRIDE         NaN               12.0
# 2  1.184627e+09  TAMSULOSIN HCL         NaN               14.0
# 3  1.306111e+09         SPIRIVA         NaN               13.0
# 4  1.285658e+09         SPIRIVA         NaN               13.0
#
#    total_30_day_fill_count  total_day_supply  total_drug_cost  \
# 0                     28.0             840.0          1009.66
# 1                     16.0             480.0           270.86
# 2                     24.0             698.0           353.62
# 3                     13.0             390.0          4783.28
# 4                     13.0             390.0          4855.95
#
#    bene_count_ge65 bene_count_ge65_suppress_flag  total_claim_count_ge65  \
# 0              NaN                             *                    18.0
# 1              NaN                             *                     NaN
# 2              NaN                             #                     NaN
# 3              NaN                             *                     NaN
# 4              NaN                             #                     NaN
#
#   ge65_suppress_flag  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# 0               None                          28.0                  840.0
# 1                  *                           NaN                    NaN
# 2                  #                           NaN                    NaN
# 3                  *                           NaN                    NaN
# 4                  #                           NaN                    NaN
#
#    total_drug_cost_ge65
# 0               1009.66
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
# prescriber table
query = "SELECT * FROM prescriber"
with engine.connect() as connection:
    prescriber = pd.read_sql(text(query), con=connection)

prescriber.head()
# Out:
#             npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1.003000e+09                    BLAKEMORE                     ROSIE
# 1  1.003012e+09                      CUDZILO                     COREY
# 2  1.003013e+09                  GRABENSTEIN                   WILLIAM
# 3  1.003014e+09                         OTTO                    ROBERT
# 4  1.003018e+09                         TODD                    JOSHUA
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0                 K               FNP                     F                 I
# 1              None              M.D.                     M                 I
# 2                 P              M.D.                     M                 I
# 3                 J              M.D.                     M                 I
# 4                 W              M.D.                     M                 I
#
#             nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# 0       TENNESSEE PRISON FOR WOMEN     3881 STEWARTS LANE           NASHVILLE
# 1              2240 SUTHERLAND AVE              SUITE 103           KNOXVILLE
# 2                 1822 MEMORIAL DR                   None         CLARKSVILLE
# 3  2400 PATTERSON STREET SUITE 100                   None           NASHVILLE
# 4                1819 W CLINCH AVE              SUITE 108           KNOXVILLE
#
#   nppes_provider_zip5 nppes_provider_zip4 nppes_provider_state  \
# 0               37243                0001                   TN
# 1               37919                2333                   TN
# 2               37043                4605                   TN
# 3               37203                2786                   TN
# 4               37916                2435                   TN
#
#   nppes_provider_country specialty_description description_flag  \
# 0                     US    Nurse Practitioner                S
# 1                     US     Pulmonary Disease                S
# 2                     US       Family Practice                S
# 3                     US    Orthopedic Surgery                S
# 4                     US            Cardiology                S
#
#   medicare_prvdr_enroll_status
# 0                            N
# 1                            E
# 2                            E
# 3                            E
# 4                            E

# %%
# for drug table
query = "SELECT * FROM drug"
with engine.connect() as connection:
    drugs = pd.read_sql(text(query), con=connection)

drugs.head()
# Out:
#                         drug_name                    generic_name  \
# 0        1ST TIER UNIFINE PENTIPS            PEN NEEDLE, DIABETIC
# 1   1ST TIER UNIFINE PENTIPS PLUS            PEN NEEDLE, DIABETIC
# 2                        ABACAVIR                ABACAVIR SULFATE
# 3             ABACAVIR-LAMIVUDINE     ABACAVIR SULFATE/LAMIVUDINE
# 4  ABACAVIR-LAMIVUDINE-ZIDOVUDINE  ABACAVIR/LAMIVUDINE/ZIDOVUDINE
#
#   opioid_drug_flag long_acting_opioid_drug_flag antibiotic_drug_flag  \
# 0                N                            N                    N
# 1                N                            N                    N
# 2                N                            N                    N
# 3                N                            N                    N
# 4                N                            N                    N
#
#   antipsychotic_drug_flag
# 0                       N
# 1                       N
# 2                       N
# 3                       N
# 4                       N

# %%
# for zip_fips and fips_county
zip_fips = pd.read_sql(text("SELECT * FROM zip_fips"), con=engine)
fips = pd.read_sql(text("SELECT * FROM fips_county"), con=engine)

# %%
# filter for opioids
opioids = drugs[drugs['opioid_drug_flag'] == 'Y']
opioids.head()
# Out:
#                         drug_name                   generic_name  \
# 10                        ABSTRAL               FENTANYL CITRATE
# 18   ACETAMIN-CAFF-DIHYDROCODEINE  ACETAMINOPHEN/CAFF/DIHYDROCOD
# 19          ACETAMINOPHEN-CODEINE     ACETAMINOPHEN WITH CODEINE
# 33                          ACTIQ               FENTANYL CITRATE
# 212                      ARYMO ER               MORPHINE SULFATE
#
#     opioid_drug_flag long_acting_opioid_drug_flag antibiotic_drug_flag  \
# 10                 Y                            N                    N
# 18                 Y                            N                    N
# 19                 Y                            N                    N
# 33                 Y                            N                    N
# 212                Y                            Y                    N
#
#     antipsychotic_drug_flag
# 10                        N
# 18                        N
# 19                        N
# 33                        N
# 212                       N

# %%
# join prescriptions to opioid list
opioid_rx = rx.merge(opioids, on="drug_name")
opioid_rx.head()
# Out:
#             npi                  drug_name  bene_count  total_claim_count  \
# 0  1.659798e+09    OXYCODONE-ACETAMINOPHEN       102.0              525.0
# 1  1.003955e+09  HYDROCODONE-ACETAMINOPHEN        14.0               79.0
# 2  1.487942e+09  HYDROCODONE-ACETAMINOPHEN         NaN               12.0
# 3  1.295730e+09               TRAMADOL HCL         NaN               26.0
# 4  1.316100e+09  HYDROCODONE-ACETAMINOPHEN        11.0               12.0
#
#    total_30_day_fill_count  total_day_supply  total_drug_cost  \
# 0                    525.0           15538.0         27665.43
# 1                     79.0            2273.0           626.75
# 2                     12.0             161.0           154.58
# 3                     26.0             657.0           112.66
# 4                     12.0              29.0            53.25
#
#    bene_count_ge65 bene_count_ge65_suppress_flag  total_claim_count_ge65  \
# 0             43.0                          None                   245.0
# 1              NaN                             *                     NaN
# 2              NaN                             *                     NaN
# 3              NaN                             #                     NaN
# 4              NaN                             *                     NaN
#
#   ge65_suppress_flag  total_30_day_fill_count_ge65  total_day_supply_ge65  \
# 0               None                         245.0                 7290.0
# 1                  *                           NaN                    NaN
# 2                  *                           NaN                    NaN
# 3                  #                           NaN                    NaN
# 4                  *                           NaN                    NaN
#
#    total_drug_cost_ge65                 generic_name opioid_drug_flag  \
# 0              12245.28  OXYCODONE HCL/ACETAMINOPHEN                Y
# 1                   NaN    HYDROCODONE/ACETAMINOPHEN                Y
# 2                   NaN    HYDROCODONE/ACETAMINOPHEN                Y
# 3                   NaN                 TRAMADOL HCL                Y
# 4                   NaN    HYDROCODONE/ACETAMINOPHEN                Y
#
#   long_acting_opioid_drug_flag antibiotic_drug_flag antipsychotic_drug_flag
# 0                            N                    N                       N
# 1                            N                    N                       N
# 2                            N                    N                       N
# 3                            N                    N                       N
# 4                            N                    N                       N

# %%
# add prescriber to zip_fips and fips
prescriber_geo = (
    prescriber
    .merge(zip_fips, left_on="nppes_provider_zip5", right_on="zip")
    .merge(fips, on="fipscounty")
)

prescriber_geo.head()
# Out:
#             npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1.003000e+09                    BLAKEMORE                     ROSIE
# 1  1.003012e+09                      CUDZILO                     COREY
# 2  1.003013e+09                  GRABENSTEIN                   WILLIAM
# 3  1.003013e+09                  GRABENSTEIN                   WILLIAM
# 4  1.003013e+09                  GRABENSTEIN                   WILLIAM
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0                 K               FNP                     F                 I
# 1              None              M.D.                     M                 I
# 2                 P              M.D.                     M                 I
# 3                 P              M.D.                     M                 I
# 4                 P              M.D.                     M                 I
#
#        nppes_provider_street1 nppes_provider_street2 nppes_provider_city  ...  \
# 0  TENNESSEE PRISON FOR WOMEN     3881 STEWARTS LANE           NASHVILLE  ...
# 1         2240 SUTHERLAND AVE              SUITE 103           KNOXVILLE  ...
# 2            1822 MEMORIAL DR                   None         CLARKSVILLE  ...
# 3            1822 MEMORIAL DR                   None         CLARKSVILLE  ...
# 4            1822 MEMORIAL DR                   None         CLARKSVILLE  ...
#
#   medicare_prvdr_enroll_status    zip fipscounty res_ratio bus_ratio  \
# 0                            N  37243      47037  0.000000  1.000000
# 1                            E  37919      47093  1.000000  1.000000
# 2                            E  37043      47125  0.996300  0.998589
# 3                            E  37043      47147  0.000084  0.000000
# 4                            E  37043      47021  0.003616  0.001411
#
#   oth_ratio tot_ratio      county state  fipsstate
# 0       1.0  1.000000    DAVIDSON    TN         47
# 1       1.0  1.000000        KNOX    TN         47
# 2       1.0  0.996572  MONTGOMERY    TN         47
# 3       0.0  0.000076   ROBERTSON    TN         47
# 4       0.0  0.003351    CHEATHAM    TN         47
#
# [5 rows x 26 columns]

# %%
# add the opioid prescriptions to the county mapped prescribers
opioid_with_county = opioid_rx.merge(prescriber_geo, on="npi")
opioid_with_county.head()
# Out:
#             npi                  drug_name  bene_count  total_claim_count  \
# 0  1.659798e+09    OXYCODONE-ACETAMINOPHEN       102.0              525.0
# 1  1.659798e+09    OXYCODONE-ACETAMINOPHEN       102.0              525.0
# 2  1.003955e+09  HYDROCODONE-ACETAMINOPHEN        14.0               79.0
# 3  1.487942e+09  HYDROCODONE-ACETAMINOPHEN         NaN               12.0
# 4  1.295730e+09               TRAMADOL HCL         NaN               26.0
#
#    total_30_day_fill_count  total_day_supply  total_drug_cost  \
# 0                    525.0           15538.0         27665.43
# 1                    525.0           15538.0         27665.43
# 2                     79.0            2273.0           626.75
# 3                     12.0             161.0           154.58
# 4                     26.0             657.0           112.66
#
#    bene_count_ge65 bene_count_ge65_suppress_flag  total_claim_count_ge65  ...  \
# 0             43.0                          None                   245.0  ...
# 1             43.0                          None                   245.0  ...
# 2              NaN                             *                     NaN  ...
# 3              NaN                             *                     NaN  ...
# 4              NaN                             #                     NaN  ...
#
#   medicare_prvdr_enroll_status    zip  fipscounty  res_ratio bus_ratio  \
# 0                            E  37311       47011   0.996995  1.000000
# 1                            E  37311       47065   0.003005  0.000000
# 2                            E  37421       47065   1.000000  1.000000
# 3                            E  37208       47037   1.000000  1.000000
# 4                            E  38583       47035   0.044379  0.007609
#
#   oth_ratio tot_ratio      county state fipsstate
# 0  0.997940  0.997417     BRADLEY    TN        47
# 1  0.002060  0.002583    HAMILTON    TN        47
# 2  1.000000  1.000000    HAMILTON    TN        47
# 3  1.000000  1.000000    DAVIDSON    TN        47
# 4  0.189189  0.042635  CUMBERLAND    TN        47
#
# [5 rows x 44 columns]

# %%
# aggregate opioid prescriptions by county
opioid_by_county = (
    opioid_with_county
    .groupby("county")["total_claim_count"]
    .sum()
    .reset_index()
    .sort_values("total_claim_count", ascending=False)
)

opioid_by_county
# Out:
#       county  total_claim_count
# 19  DAVIDSON           320821.0
# 47      KNOX           280484.0
# 79    SHELBY           240211.0
# 33  HAMILTON           229988.0
# 82  SULLIVAN           141375.0
# ..       ...                ...
# 81   STEWART             3216.0
# 21   DECATUR             2371.0
# 48      LAKE              220.0
# 85    TRAVIS               40.0
# 6     BROOKS               20.0
#
# [97 rows x 2 columns]

# %%
opioid_by_county.head(15)
# Out:
#         county  total_claim_count
# 19    DAVIDSON           320821.0
# 47        KNOX           280484.0
# 79      SHELBY           240211.0
# 33    HAMILTON           229988.0
# 82    SULLIVAN           141375.0
# 91  WASHINGTON           111925.0
# 95  WILLIAMSON           104875.0
# 10      CARTER           100532.0
# 37     HAWKINS            99832.0
# 75  RUTHERFORD            83305.0
# 83      SUMNER            82216.0
# 55     MADISON            79787.0
# 9      CARROLL            78063.0
# 26    FRANKLIN            69226.0
# 73       ROANE            69217.0

# %%
# normalize by population?

# %%
# Tennessee's Opioid Crisis
# Opioids are a class of drugs including prescription pain relievers such as oxycodone and hydrocodone, the synthetic opioid fentanyl,
# and the illegal drug heroin. These drugs produce euphoria in addition to pain relief, which can lead to dependence, addiction,
# overdose, and death.

# In the late 1990s, opioids began to be prescribed at high rates, which led to widespread misuse and ultimately created a serious
# national health crisis. In 2019, more than 130 people per day died from opioid-related drug overdoses in the United States. 
# Tennessee has been one of the hardest-hit states in the opioid epidemic, with more than 1300 overdose deaths in 2018.
    
# In this project, you will be working with a database created from the 2017 Medicare Part D Prescriber Public Use File to answer the
# following questions:
# ⦁	Which Tennessee counties had a disproportionately high number of opioid prescriptions?
# ⦁	Who are the top opioid prescibers for the state of Tennessee?
# ⦁	What did the trend in overdose deaths due to opioids look like in Tennessee from 2015 to 2018?
# ⦁	Is there an association between rates of opioid prescriptions and overdose deaths by county?
# ⦁	Is there any association between a particular type of opioid and number of overdose deaths?
# Note that some zip codes will be associated with multiple fipscounty values in the zip_fips table. To resolve this, use the
# fipscounty with the highest tot_ratio for each zipcode.
    
# Feel free to include any additional data sets, but it is not a requirement.
# With your group, create a 10 minute presentation addressing these questions.
